# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Mall_Customers.csv',encoding='latin')
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,3,1)
sns.barplot(x=df['Gender'],y=df['Annual Income (k$)'])
plt.subplot(1,3,2)
sns.barplot(x=df['Gender'],y=df['Spending Score (1-100)'])
plt.subplot(1,3,3)
sns.barplot(x=df['Gender'],y=df['Age'])
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,3,1)
sns.boxplot(x=df['Gender'],y=df['Annual Income (k$)'])
plt.subplot(1,3,2)
sns.boxplot(x=df['Gender'],y=df['Spending Score (1-100)'])
plt.subplot(1,3,3)
sns.boxplot(x=df['Gender'],y=df['Age'])
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
df['Gender'] = df['Gender'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    category
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: category(1), int64(4)
# memory usage: 6.7 KB

# %%
df['Gender'] = df['Gender'].cat.codes
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1       1   19                  15                      39
# 1             2       1   21                  15                      81
# 2             3       0   20                  16                       6
# 3             4       0   23                  16                      77
# 4             5       0   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196       0   35                 120                      79
# 196         197       0   45                 126                      28
# 197         198       1   32                 126                      74
# 198         199       1   32                 137                      18
# 199         200       1   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df_new = df.drop(columns=['CustomerID'])
df_new
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0         1   19                  15                      39
# 1         1   21                  15                      81
# 2         0   20                  16                       6
# 3         0   23                  16                      77
# 4         0   31                  17                      40
# ..      ...  ...                 ...                     ...
# 195       0   35                 120                      79
# 196       0   45                 126                      28
# 197       1   32                 126                      74
# 198       1   32                 137                      18
# 199       1   30                 137                      83
#
# [200 rows x 4 columns]

# %%
df_new = df_new.rename(columns={'Annual Income (k$)':'Annual_Income','Spending Score (1-100)':'Spending_Score'})
df_new
# Out:
#      Gender  Age  Annual_Income  Spending_Score
# 0         1   19             15              39
# 1         1   21             15              81
# 2         0   20             16               6
# 3         0   23             16              77
# 4         0   31             17              40
# ..      ...  ...            ...             ...
# 195       0   35            120              79
# 196       0   45            126              28
# 197       1   32            126              74
# 198       1   32            137              18
# 199       1   30            137              83
#
# [200 rows x 4 columns]

# %%
scaler = StandardScaler()
df_new_scaled = pd.DataFrame(scaler.fit_transform(df_new),columns=['Gender','Age','Annual_Income','Spending_Score'])
df_new_scaled
# Out:
#        Gender       Age  Annual_Income  Spending_Score
# 0    1.128152 -1.424569      -1.738999       -0.434801
# 1    1.128152 -1.281035      -1.738999        1.195704
# 2   -0.886405 -1.352802      -1.700830       -1.715913
# 3   -0.886405 -1.137502      -1.700830        1.040418
# 4   -0.886405 -0.563369      -1.662660       -0.395980
# ..        ...       ...            ...             ...
# 195 -0.886405 -0.276302       2.268791        1.118061
# 196 -0.886405  0.441365       2.497807       -0.861839
# 197  1.128152 -0.491602       2.497807        0.923953
# 198  1.128152 -0.491602       2.917671       -1.250054
# 199  1.128152 -0.635135       2.917671        1.273347
#
# [200 rows x 4 columns]

# %%
sse =[]
for i in range(1,10):
  kmeans = KMeans(n_clusters = i,random_state=1).fit(df_new_scaled)
  sse.append(kmeans.inertia_)
sns.lineplot(x=list(range(1,10)),y=sse,color='red')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: >

# %%
sil = []
for i in range(2,10):
  kmeans = KMeans(n_clusters=i,random_state=1).fit(df_new_scaled)
  labels = kmeans.predict(df_new_scaled)
  sil.append(silhouette_score(df_new_scaled,labels))
sns.lineplot(x=list(range(2,10)),y=sil)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: >

# %%
kmeans = KMeans(n_clusters = 4,random_state=1).fit(df_new_scaled)
labels = kmeans.predict(df_new_scaled)
df_new['KMeans_Labels'] = labels
df_new
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#      Gender  Age  Annual_Income  Spending_Score  KMeans_Labels
# 0         1   19             15              39              3
# 1         1   21             15              81              3
# 2         0   20             16               6              2
# 3         0   23             16              77              1
# 4         0   31             17              40              2
# ..      ...  ...            ...             ...            ...
# 195       0   35            120              79              1
# 196       0   45            126              28              2
# 197       1   32            126              74              3
# 198       1   32            137              18              0
# 199       1   30            137              83              3
#
# [200 rows x 5 columns]

# %%
df['KMeans_Labels'] = labels
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1       1   19                  15                      39
# 1             2       1   21                  15                      81
# 2             3       0   20                  16                       6
# 3             4       0   23                  16                      77
# 4             5       0   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196       0   35                 120                      79
# 196         197       0   45                 126                      28
# 197         198       1   32                 126                      74
# 198         199       1   32                 137                      18
# 199         200       1   30                 137                      83
#
#      KMeans_Labels
# 0                3
# 1                3
# 2                2
# 3                1
# 4                2
# ..             ...
# 195              1
# 196              2
# 197              3
# 198              0
# 199              3
#
# [200 rows x 6 columns]

# %%
mean = df.groupby('KMeans_Labels').mean()
median = df.groupby('KMeans_Labels').median()
df_new_compare = pd.concat([mean,median],axis=0)
df_new_compare.index = ['g0 mean', 'g0 median', 'g1 mean', 'g1 median','g2 mean','g2 median','g3 mean','g3 median']
df_new_compare.T
# Out:
#                            g0 mean   g0 median    g1 mean  g1 median  g2 mean  \
# CustomerID              104.958333  101.910714  93.214286    103.375    106.5
# Gender                    1.000000    0.000000   0.000000      1.000      1.0
# Age                      49.437500   28.392857  47.803571     28.250     48.5
# Annual Income (k$)       62.416667   60.428571  58.071429     62.000     62.5
# Spending Score (1-100)   29.208333   68.178571  34.875000     71.675     32.0
#
#                         g2 median  g3 mean  g3 median
# CustomerID                  109.0     85.5      109.0
# Gender                        0.0      0.0        1.0
# Age                          29.5     48.0       28.0
# Annual Income (k$)           62.5     55.5       63.0
# Spending Score (1-100)       73.0     39.5       73.0

# %%
cols = ['Age','Annual Income (k$)','Spending Score (1-100)','KMeans_Labels']
for col in cols:
  plt.figure(figsize=(10,5))
  sns.barplot(x=df['Gender'],y=col,data=df)
  plt.show()

# %%
cols = ['Gender','Age','Spending Score (1-100)']
for col in cols:
  plt.figure(figsize=(10,5))
  sns.scatterplot(x='Annual Income (k$)',y=col,hue='KMeans_Labels',data=df,palette='Dark2')
  plt.show()

# %%
cols = ['Age','Spending Score (1-100)','Annual Income (k$)']
for col in cols:
  plt.figure(figsize=(10,5))
  sns.violinplot(x='Gender',y=col,data=df,palette='Dark2')
  plt.show()
